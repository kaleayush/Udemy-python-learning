# %% [markdown]
# # Module 5: Modules and Packages Assignments
# ## Lesson 5.1: Importing Modules
# ### Assignment 1: Importing and Using Modules
#
# Import the `math` module and use it to calculate the square root of 25 and the sine of 90 degrees.
#
# ### Assignment 2: Aliasing Modules
#
# Import the `datetime` module with an alias and use it to print the current date and time.
#
# ### Assignment 3: Importing Specific Functions
#
# Import the `randint` function from the `random` module and use it to generate a random integer between 1 and 100.
#
# ### Assignment 4: Importing Multiple Functions
#
# Import the `sqrt` and `pow` functions from the `math` module and use them to calculate the square root of 16 and 2 raised to the power of 3.
#
# ### Assignment 5: Handling Import Errors
#
# Write code that attempts to import a non-existent module and gracefully handles the import error by printing an error message.
#
# ## Lesson 5.2: Standard Library Overview
# ### Assignment 6: Working with the `os` Module
#
# Use the `os` module to create a new directory, list the contents of the current directory, and remove the newly created directory.
#
# ### Assignment 7: Working with the `sys` Module
#
# Use the `sys` module to print the Python version currently in use and the command-line arguments passed to the script.
#
# ### Assignment 8: Working with the `math` Module
#
# Use the `math` module to calculate the greatest common divisor (GCD) of two numbers and the factorial of a number.
#
# ### Assignment 9: Working with the `datetime` Module
#
# Use the `datetime` module to print the current date, calculate the date 100 days from today, and determine the day of the week for a given date.
#
# ### Assignment 10: Working with the `random` Module
#
# Use the `random` module to generate a list of 5 random numbers between 1 and 50 and shuffle the elements of a list.
#
# ## Lesson 5.3: Creating and Using Packages
# ### Assignment 11: Creating a Simple Package
#
# Create a package named `mypackage` with two modules: `module1` and `module2`. `module1` should contain a function that adds two numbers, and `module2` should contain a function that multiplies two numbers. Write code to use these functions.
#
# ### Assignment 12: Using `__init__.py`
#
# Modify the `mypackage` package to include an `__init__.py` file that imports the functions from `module1` and `module2`. Write code to use these functions.
#
# ### Assignment 13: Importing from a Package
#
# Write code to import and use the functions from `mypackage` without explicitly importing `module1` and `module2`.
#
# ### Assignment 14: Relative Imports
#
# Create a subpackage named `subpackage` within `mypackage` and move `module2` into `subpackage`. Modify the import statements in `__init__.py` to use relative imports. Write code to use the functions from both modules.
#
# ### Assignment 15: Handling Package Import Errors
#
# Write code that attempts to import a non-existent function from `mypackage` and gracefully handles the import error by printing an error message.

# %%
### Assignment 1: Importing and Using Modules

# Import the `math` module and use it to calculate the square root of 25 and the sine of 90 degrees.
from math import sqrt
print(sqrt(25))
# Out:
# 5.0

# %%
### Assignment 2: Aliasing Modules

# Import the `datetime` module with an alias and use it to print the current date and time.
import datetime as dt
print(dt.datetime.now())
# Out:
# 2026-04-22 17:24:07.137385

# %%
### Assignment 3: Importing Specific Functions

# Import the `randint` function from the `random` module and use it to generate a random integer between 1 and 100.
from random import randint
print(randint(1,10))
# Out:
# 3

# %%
### Assignment 4: Importing Multiple Functions

# Import the `sqrt` and `pow` functions from the `math` module and use them to calculate the square root of 16 and 2 raised to the power of 3.
from math import sqrt, pow
print(sqrt(16))
print(pow(2,3))
# Out:
# 4.0
# 8.0

# %%
### Assignment 5: Handling Import Errors

# Write code that attempts to import a non-existent module and gracefully handles the import error by printing an error message.

try :
    import non_existent_module
except ImportError as Ie:
    print(f"error importing module : {Ie}")
# Out:
# error importing module : No module named 'non_existent_module'

# %%
## Lesson 5.2: Standard Library Overview
### Assignment 6: Working with the `os` Module

# Use the `os` module to create a new directory, list the contents of the current directory, and remove the newly created directory.

import os
os.mkdir('text1.txt')
os.listdir('.')
os.rmdir('text.txt')

# %%
### Assignment 7: Working with the `sys` Module

# Use the `sys` module to print the Python version currently in use and the command-line arguments passed to the script.

import sys
print(sys.version)
print(sys.argv)
# Out:
# 3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:09:58) [MSC v.1929 64 bit (AMD64)]
# ['e:\\anaconda3\\Lib\\site-packages\\ipykernel_launcher.py', '--f="c:\\Users\\Ayush kale\\AppData\\Roaming\\jupyter\\runtime\\kernel-v3dfb2f9752e9667505de53b95df936f85bf32e785.json"']

# %%
### Assignment 8: Working with the `math` Module

# Use the `math` module to calculate the greatest common divisor (GCD) of two numbers and the factorial of a number.
from math import factorial, gcd
print(factorial(5))
print(gcd(21,14 ,28))
# Out:
# 120
# 7

# %%
### Assignment 9: Working with the `datetime` Module

# Use the `datetime` module to print the current date, calculate the date 100 days from today, and determine the day of the week for a given date.

import datetime
current_date = datetime.date.today()
print(current_date)
datAfter = current_date + datetime.timedelta(100)
print(datAfter)
day=datetime.date(2026, 7, 15)
print(f"day of week{day.strftime('%A')}")
# Out:
# 2026-04-22
# 2026-07-31
# day of weekWednesday

# %%
### Assignment 10: Working with the `random` Module

# Use the `random` module to generate a list of 5 random numbers between 1 and 50 and shuffle the elements of a list.

import random

random_no = [random.randint(1, 50) for i in range(5)]
print(random_no)

lst = [1,2,3,4]
random.shuffle(lst)
print(lst)
# Out:
# [33, 5, 19, 3, 15]
# [4, 1, 2, 3]

# %%
## Lesson 5.3: Creating and Using Packages
### Assignment 11: Creating a Simple Package

# Create a package named `mypackage` with two modules: `module1` and `module2`. `module1` should contain a function that adds two numbers, and `module2` should contain a 
# function that multiplies two numbers. Write code to use these functions.

# File structure:
# mypackage/
#   __init__.py
#   module1.py
#   module2.py

# Content of module1.py
# def add(a, b):
#     return a + b

# Content of module2.py
# def multiply(a, b):
#     return a * b

from mypackage.module1 import multi
from mypackage.module2 import add

print(multi(10,4))
print(add(23,34))
# Out:
# 40
# 57

# %%
### Assignment 12: Using `__init__.py`

# Modify the `mypackage` package to include an `__init__.py` file that imports the functions from `module1` and `module2`. Write code to use these functions.

from mypackage import add, multi
print(add(20,30))
print(multi(4,5))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[39], line 5
#       1 ### Assignment 12: Using `__init__.py`
#       2
#       3 # Modify the `mypackage` package to include an `__init__.py` file that imports the functions from `module1` and `module2`. Write code to use these functions.
# ----> 5 from mypackage import add, multi
#       6 print(add(20,30))
#       7 print(multi(4,5))
#
# ImportError: cannot import name 'add' from 'mypackage' (e:\Python\08Modules\mypackage\__init__.py)

# %%
### Assignment 13: Importing from a Package

# Write code to import and use the functions from `mypackage` without explicitly importing `module1` and `module2`.

from mypackage import add, multi
print(add(20,30))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[40], line 5
#       1 ### Assignment 13: Importing from a Package
#       2
#       3 # Write code to import and use the functions from `mypackage` without explicitly importing `module1` and `module2`.
# ----> 5 from mypackage import add, multi
#       6 print(add(20,30))
#
# ImportError: cannot import name 'add' from 'mypackage' (e:\Python\08Modules\mypackage\__init__.py)

# %%
### Assignment 14: Relative Imports

# Create a subpackage named `subpackage` within `mypackage` and move `module2` into `subpackage`.
#  Modify the import statements in `__init__.py` to use relative imports. Write code to use the functions from both modules.


from mypackage import multi
print(add(20,30))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[46], line 7
#       1 ### Assignment 14: Relative Imports
#       2
#       3 # Create a subpackage named `subpackage` within `mypackage` and move `module2` into `subpackage`.
#       4 #  Modify the import statements in `__init__.py` to use relative imports. Write code to use the functions from both modules.
# ----> 7 from mypackage import multi
#       8 print(add(20,30))
#
# ImportError: cannot import name 'multi' from 'mypackage' (e:\Python\08Modules\mypackage\__init__.py)

# %%
### Assignment 15: Handling Package Import Errors

# Write code that attempts to import a non-existent function from `mypackage` and gracefully handles the import error by printing an error message.
try :
    from mypackage import non_exising_function 
except ImportError as ie:
    print(f"error importing function{ie}")
# Out:
# error importing functioncannot import name 'non_exising_function' from 'mypackage' (e:\Python\08Modules\mypackage\__init__.py)
