# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
# Your code here
print("Hello, World!")

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
# Your code here
res= input("Enter your name")
print(f"your name is :{res}")
# Out:
# Ayush

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
# Your code here
num =  int(input("enter your age"))
type(num)
if num >0:
    print("No is positive")
elif num < 0 :
    print("No is negative")
else:
    print("No is Zero")

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
# Your code here
num1 = int(input("Enter First Number"))
num2 = int(input("Enter Second Number"))
num3 = int(input("Enter Third Number"))

if num1 > num2 and num1 > num3:
    print("num1 is grater:", num )
elif num2 > num3:
    print("num2 is grater:", num2)
else:
    print("num3 is grater:", num3)

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
# Your code here
def fact (num):
    if num == 0 :
        return 1 
    else :
        return num * fact(num -1)

num = int(input("Enter no to find factorial"))
result = fact(num)
print(f'factorial of {num} :', result )
# Out:
# factorial of 5 : 120

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
# Your code here
age = 25
is_user =True
name= "ayush"
height= 5.7
print(type(age), age)
print(type(is_user), is_user)
print(type(name), name)
print(type(height), height)
# Out:
# <class 'int'> 25
# <class 'bool'> True
# <class 'str'> ayush
# <class 'float'> 5.7

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
# Your code here
a= 10
b=20
a ,b =b, a
print(a)
print(b)
# Out:
# 20
# 10

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
# Your code here
celsius = float(input("Enter celsius"))
feh = (celsius*9/5) + 32
print(f"{celsius} celsuis to fahrenheit {feh}")
# Out:
# 768

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
# Your code here
first_name = "ayush"
last_Name = "Kale"
full_Name = first_name +" "+last_Name
print(full_Name)
# Out:
# ayushKale

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
# Your code here
age1 = 35
if isinstance(age1, int):
    print(f"Data type of age is integer")
else:
    print(f"Data type is not integer")

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
# Your code here
a =10 ; b=20
addition= a +b
sub = a-b
multi= a*b
div= a/b
print(addition, sub, multi, div)
# Out:
# 30 -10 200 0.5

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
# Your code here
a= 10; b=20
if a == b:
    print("equal")
elif a>b:
    print("a is grater")
elif a != b :
    print("not equal to")
# Out:
# not equal to

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
# Your code here
a = True, 
b = False

print(a and b)
print(a or b)
print(not a)
# Out:
# False
# (True,)
# False

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
# Your code here
num = int(input("Enter any number for sqare"))
print(f"Square of a {num} :", num**2)
# Out:
# Square of a 5 : 25

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
# Your code here
num = int(input("Enter number"))
if num%2 ==0:
    print("num is even")
else: 
    print("num is odd")
# Out:
# num is odd

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
# Your code here
n_natural_no = int(input("Enter natural number"))
total_sum= (n_natural_no * (n_natural_no-1))//2
print(f"total sum of first n natural number" ,total_sum)
# Out:
# total sum of first n natural number 45.0

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
# Your code here
year = int(input("Enter year"))
if(year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print(f"Year is a leap year")
else :
    print(f"not a leap year")
# Out:
# Year is a leap year

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
# Your code here
Str= input("Enter any string")
rev = Str[::-1]
print(rev)
# Out:
# eman

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
# Your code here
Str = input("Enter any string value")
palindrome = Str[::-1]
print(palindrome)
if(Str == palindrome ):
    print("the string is palindrome")
# Out:
# ayushhsuya
# the string is palindrome

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
# Your code here
num = [int(x) for x in input("enter number with comma").split()]
num.sort()
print(num)
# Out:
# [85455568845]
