# %%
import logging
logger1 = logging.getLogger('logger1')
logger1.setLevel(logging.DEBUG)

logger2 = logging.getLogger('logger2')
logger2.setLevel(logging.WARNING)

logging.basicConfig(
                    filename='app.log',
                    filemode='w',
                    level=logging.DEBUG,
                    format = '%(asctime)s-%(name)s-%(levelname)s-%(message)s',
                    datefmt='%Y-%M-%D %H-%M-%S'
                    )

# logging.debug("this is debug message")
# logging.info("this is info message")
# logging.warning("this is warning message")
# logging.error("this is error message")
# logging.critical("this is critical message")

# %%
logger1.debug("this is debug message from logger1")
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\Users\ayush\AppData\Local\Programs\Python\Python314\Lib\logging\__init__.py", line 472, in format
#     return self._format(record)
#            ~~~~~~~~~~~~^^^^^^^^
#   File "c:\Users\ayush\AppData\Local\Programs\Python\Python314\Lib\logging\__init__.py", line 468, in _format
#     return self._fmt % values
#            ~~~~~~~~~~^~~~~~~~
# KeyError: 'levename'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\ayush\AppData\Local\Programs\Python\Python314\Lib\logging\__init__.py", line 1151, in emit
#     msg = self.format(record)
#   File "c:\Users\ayush\AppData\Local\Programs\Python\Python314\Lib\logging\__init__.py", line 999, in format
#     return fmt.format(record)
#            ~~~~~~~~~~^^^^^^^^
#   File "c:\Users\ayush\AppData\Local\Programs\Python\Python314\Lib\logging\__init__.py", line 715, in format
#     s = self.formatMessage(record)
#   File "c:\Users\ayush\AppData\Local\Programs\Python\Python314\Lib\logging\__init__.py", line 684, in formatMessage
#     return self._style.format(record)
#            ~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "c:\Users\ayush\AppData\Local\Programs\Python\Python314\Lib\logging\__init__.py", line 474, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'levename'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\ayush\AppData\Roaming\Python\Python314\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\ayush\AppData\Roaming\Python\Python314\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\ayush\AppData\Roaming\Python\Python314\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "C:\Users\ayush\AppData\Roaming\Python\Python314\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\ayush\AppData\Local\Programs\Python\Python314\Lib\asyncio\base_events.py", line 677, in run_forever
#     self._run_once()
#   File "c:\Users\ayush\AppData\Local\Programs\Python\Python314\Lib\asyncio\base_events.py", line 2046, in _run_once
#     handle._run()
#   File "c:\Users\ayush\AppData\Local\Programs\Python\Python314\Lib\asyncio\events.py", line 94, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\ayush\AppData\Roaming\Python\Python314\site-packages\ipykernel\kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "C:\Users\ayush\AppData\Roaming\Python\Python314\site-packages\ipykernel\kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "C:\Users\ayush\AppData\Roaming\Python\Python314\site-packages\ipykernel\ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\ayush\AppData\Roaming\Python\Python314\site-packages\ipykernel\kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\ayush\AppData\Roaming\Python\Python314\site-packages\ipykernel\ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\ayush\AppData\Roaming\Python\Python314\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\ayush\AppData\Roaming\Python\Python314\site-packages\IPython\core\interactiveshell.py", line 3169, in run_cell
#     result = self._run_cell(
#   File "C:\Users\ayush\AppData\Roaming\Python\Python314\site-packages\IPython\core\interactiveshell.py", line 3224, in _run_cell
#     result = runner(coro)
#   File "C:\Users\ayush\AppData\Roaming\Python\Python314\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\ayush\AppData\Roaming\Python\Python314\site-packages\IPython\core\interactiveshell.py", line 3446, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\ayush\AppData\Roaming\Python\Python314\site-packages\IPython\core\interactiveshell.py", line 3687, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\ayush\AppData\Roaming\Python\Python314\site-packages\IPython\core\interactiveshell.py", line 3747, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\ayush\AppData\Local\Temp\ipykernel_25304\3390109706.py", line 1, in <module>
#     logger1.debug("this is debug message from logger1")
# Message: 'this is debug message from logger1'
# Arguments: ()
