# %% [markdown]
# Importing modules in python :modules and packages
#
# in python modules and pakages helps in organize and reuse code

# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt , pi
print(sqrt(16))
print(pi)
# Out:
# 4.0
# 3.141592653589793

# %%
# %pip install numpy
# Out:
# Running cells with 'venv1 (Python 3.11.15)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n venv1 ipykernel --update-deps --force-reinstall'

# %%
import numpy as np
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])
