# %%
import array
print(array.array( "i", [1,2,3,4,5]))
# Out:
# array('i', [1, 2, 3, 4, 5])

# %%
from math import sqrt
print(sqrt(16))
# Out:
# 4.0

# %%
import random
print(random.randint(1,10))
print(random.choice(["apple" , "banana" ,"Cherry"]))
# Out:
# 6
# apple

# %%
import os 
# used for file and director access
print(os.getcwd())
os.mkdir("test_dir")
# Out:
# e:\Python\Learning\modules

# %%
#high leve opearation of files and collection of files

import shutil
shutil.copy("source.txt", "destination.txt")
# Out:
# 'destination.txt'

# %%
# data serialization
import json
data ={"name" : "ayush" , "age" : 25}
json_data=json.dumps(data)
print(json_data)
print(type(json_data))
past_data=json.loads(json_data)
print(past_data)
print(type(past_data))
# Out:
# {"name": "ayush", "age": 25}
# <class 'str'>
# {'name': 'ayush', 'age': 25}
# <class 'dict'>

# %%
#csv
import csv
with open("example.csv" ,mode='w', newline="") as file:
    writer = csv.writer(file) 
    writer.writerow(["name" , "ayush"])
    writer.writerow(["age", 25])

with open("example.csv" ,mode ="r") as file1:
    reader =csv.reader(file1)
    for row in reader:
        print(row)
# Out:
# ['name', 'ayush']
# ['age', '25']

# %%
from datetime import timedelta , datetime
cureent_date=datetime.now()
print(cureent_date)

yesterdate= cureent_date - timedelta(days=1)
print(yesterdate)
# Out:
# 2026-03-18 18:34:27.659590
# 2026-03-17 18:34:27.659590

# %%
import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1773839139.6652079
# 1773839141.6665623

# %%
import re
pattern = r'\d+'
text = "there are 123 apples"
match=re.search(pattern, text)
print(match.group())
# Out:
# 123
