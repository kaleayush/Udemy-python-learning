# %%
print('hello')
# Out:
# hello

# %%
## Indentation 
age = 35
if age > 32 :
    print("age is greather")
# Out:
# age is greather

# %%
## multiple statement in single line

x= 10; y =20 ; z = x+y
print(z)
# Out:
# 30

# %%
## line continuation 
total = 10+20+30+\
40+50
print(total)
# Out:
# 150

# %%
print(type(age))
print(type(total))

name = "ayush"
print(type(name))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(type(age))
#       2 print(type(total))
#       4 name = "ayush"
#
# NameError: name 'age' is not defined
