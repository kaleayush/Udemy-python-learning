# %%
## integers example
age = 35
type(age)
# Out:
# int

# %%
## floating datatype
height =5.11
type(height)
print(type(height))
# Out:
# <class 'float'>

# %%
## string datatype example
name= "ayush"
print(type(name))
# Out:
# <class 'str'>

# %%
is_True = False
print(type(is_True))
# Out:
# <class 'bool'>
