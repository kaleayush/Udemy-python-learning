# %%
import pandas as pd

# %%
df = pd.read_csv('annual-enterprise.csv')
df.describe()
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2024                     Level 1                99999
# 1      2024                     Level 1                99999
# 2      2024                     Level 1                99999
# 3      2024                     Level 1                99999
# 4      2024                     Level 1                99999
# ...     ...                         ...                  ...
# 55615  2013                     Level 3                 ZZ11
# 55616  2013                     Level 3                 ZZ11
# 55617  2013                     Level 3                 ZZ11
# 55618  2013                     Level 3                 ZZ11
# 55619  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
## handling messing value

# %%
df.isnull()
df.isnull().any(axis =1)
df.isnull().any()
df.isnull().sum()
# to find null valude in data
# Out:
# Year                           0
# Industry_aggregation_NZSIOC    0
# Industry_code_NZSIOC           0
# Industry_name_NZSIOC           0
# Units                          0
# Variable_code                  0
# Variable_name                  0
# Variable_category              0
# Value                          0
# Industry_code_ANZSIC06         0
# dtype: int64

# %%
#  To fill missing value
df.fillna(10)
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2024                     Level 1                99999
# 1      2024                     Level 1                99999
# 2      2024                     Level 1                99999
# 3      2024                     Level 1                99999
# 4      2024                     Level 1                99999
# ...     ...                         ...                  ...
# 55615  2013                     Level 3                 ZZ11
# 55616  2013                     Level 3                 ZZ11
# 55617  2013                     Level 3                 ZZ11
# 55618  2013                     Level 3                 ZZ11
# 55619  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
#filling missing value with mean if value
df['sales_fillNA'] = df['Year'].fillna(df['Year'].mean())
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2024                     Level 1                99999
# 1      2024                     Level 1                99999
# 2      2024                     Level 1                99999
# 3      2024                     Level 1                99999
# 4      2024                     Level 1                99999
# ...     ...                         ...                  ...
# 55615  2013                     Level 3                 ZZ11
# 55616  2013                     Level 3                 ZZ11
# 55617  2013                     Level 3                 ZZ11
# 55618  2013                     Level 3                 ZZ11
# 55619  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
# change the data type 
df.dtypes
# Out:
# Year                            int64
# Industry_aggregation_NZSIOC    object
# Industry_code_NZSIOC           object
# Industry_name_NZSIOC           object
# Units                          object
# Variable_code                  object
# Variable_name                  object
# Variable_category              object
# Value                          object
# Industry_code_ANZSIC06         object
# sales_fillNA                    int64
# dtype: object

# %%
## renaming columns 
df.rename(columns = {'Year': 'sales Year'})
df['Value']
# Out:
# 0        979594
# 1        838626
# 2        112188
# 3         28781
# 4        856960
#           ...
# 55615        52
# 55616        40
# 55617        12
# 55618         5
# 55619        46
# Name: Value, Length: 55620, dtype: object

# %%
#change datatype 
df['Value_new'] = df['Value'].astype(object)
df.head()
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2024                     Level 1                99999       All industries
# 1  2024                     Level 1                99999       All industries
# 2  2024                     Level 1                99999       All industries
# 3  2024                     Level 1                99999       All industries
# 4  2024                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
# 2  Dollars (millions)           H05
# 3  Dollars (millions)           H07
# 4  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# ...

# %%
df['new_Value'] = df['Value'].apply(lambda x: x*2)

# %%
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2024                     Level 1                99999
# 1      2024                     Level 1                99999
# 2      2024                     Level 1                99999
# 3      2024                     Level 1                99999
# 4      2024                     Level 1                99999
# ...     ...                         ...                  ...
# 55615  2013                     Level 3                 ZZ11
# 55616  2013                     Level 3                 ZZ11
# 55617  2013                     Level 3                 ZZ11
# 55618  2013                     Level 3                 ZZ11
# 55619  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
## data aggregating and grouping
df=pd.read_csv('products-100.csv')
print(df)
df.head()
# print(df.dtypes)
# grouped_mean = df.groupby('Year')['Value']

# print(f"data :" ,grouped_mean)
# Out:
#     Index                                   Name  \
# 0       1   Compact Printer Air Advanced Digital
# 1       2                                 Tablet
# 2       3                   Smart Blender Cooker
# 3       4           Advanced Router Rechargeable
# 4       5           Portable Mouse Monitor Phone
# ..    ...                                    ...
# 95     96                                 Router
# 96     97     Fast Thermostat Microphone Scooter
# 97     98  Eco Heater Toaster Stove Silent Sense
# 98     99               Clean Blender Scale Lite
# 99    100                             Smart Lamp
#
#                                           Description  \
# 0       Situation organization these memory much off.
# 1         Discussion loss politics free one thousand.
# 2                                   No situation per.
# 3                     For force gas energy six laugh.
# 4   Feeling back religious however author room sci...
# ...

# %%
df.head()

grouped_mean = df.groupby(['Brand', 'Color'])['Price'].mean()
print(grouped_mean)
# Out:
# Brand                      Color
# Ali-Oliver                 DarkOrchid      982.0
# Atkinson Inc               Gainsboro       375.0
# Barker-Murphy              OliveDrab       982.0
# Barnes-Glass               LightBlue       640.0
# Barron-Little              Violet          511.0
#                                            ...
# Werner PLC                 LightCoral      259.0
# West Ltd                   OldLace         232.0
# Whitney Group              BlueViolet      352.0
# Williamson PLC             Moccasin        913.0
# Zimmerman, Barr and Davis  MediumOrchid    999.0
# Name: Price, Length: 100, dtype: float64

# %%
from click import group


group_sum= df.groupby(['Brand', 'Color'])['Price'].sum()
print(group_sum)
# Out:
# Brand                      Color
# Ali-Oliver                 DarkOrchid      982
# Atkinson Inc               Gainsboro       375
# Barker-Murphy              OliveDrab       982
# Barnes-Glass               LightBlue       640
# Barron-Little              Violet          511
#                                           ...
# Werner PLC                 LightCoral      259
# West Ltd                   OldLace         232
# Whitney Group              BlueViolet      352
# Williamson PLC             Moccasin        913
# Zimmerman, Barr and Davis  MediumOrchid    999
# Name: Price, Length: 100, dtype: int64

# %%
# aggregate multiple functions
grouped_age= df.groupby(['Brand', 'Color'])['Price'].agg(['mean', 'sum','count'])
print(grouped_age)
# Out:
#                                          mean  sum  count
# Brand                     Color
# Ali-Oliver                DarkOrchid    982.0  982      1
# Atkinson Inc              Gainsboro     375.0  375      1
# Barker-Murphy             OliveDrab     982.0  982      1
# Barnes-Glass              LightBlue     640.0  640      1
# Barron-Little             Violet        511.0  511      1
# ...                                       ...  ...    ...
# Werner PLC                LightCoral    259.0  259      1
# West Ltd                  OldLace       232.0  232      1
# Whitney Group             BlueViolet    352.0  352      1
# Williamson PLC            Moccasin      913.0  913      1
# Zimmerman, Barr and Davis MediumOrchid  999.0  999      1
#
# [100 rows x 3 columns]

# %%
## mering and joining Dataframes
df1= pd.DataFrame({'key' : ['a', 'b','c'], 'Value1':[1,2,3]})
df2= pd.DataFrame({'key' : ['a', 'b','d'], 'Value1':[4,5,6]})
df1
# Out:
#   key  Value1
# 0   a       1
# 1   b       2
# 2   c       3

# %%
df2
# Out:
#   key  Value1
# 0   a       4
# 1   b       5
# 2   d       6

# %%
pd.merge(df1, df2 , on="key", how= 'inner')
# Out:
#   key  Value1_x  Value1_y
# 0   a         1         4
# 1   b         2         5

# %%
pd.merge(df1, df2 , on="key", how= 'outer')
# Out:
#   key  Value1_x  Value1_y
# 0   a       1.0       4.0
# 1   b       2.0       5.0
# 2   c       3.0       NaN
# 3   d       NaN       6.0

# %%
pd.merge(df1, df2 , on="key", how= 'left')
# Out:
#   key  Value1_x  Value1_y
# 0   a         1       4.0
# 1   b         2       5.0
# 2   c         3       NaN

# %%
pd.merge(df1, df2 , on="key", how= 'right')
# Out:
#   key  Value1_x  Value1_y
# 0   a       1.0         4
# 1   b       2.0         5
# 2   d       NaN         6
