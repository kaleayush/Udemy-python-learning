# %%
## read the whole file
with open(file="example.text" , mode ="r" )  as file:
    content = file.read()
    print(content)
# Out:
# Conversational Interfaces: Users interact via chatbots or voice assistants (such as: asking questions, getting recommendations).
# Embedded Features: AI is integrated into apps for tasks like autocomplete, image recognition, or fraud detection.
# Decision Support: AI applications provide insights or predictions to help users make informed choices (such as: personalized shopping, medical diagnostics).
# Automation: They handle repetitive tasks, such as document processing or customer service, reducing manual effort.

# %%
## read the file line by line
with open(file= "example.text" , mode= "r") as file:
    for line in file:
        print(line.strip())
#strip remove new empty line after line
# Out:
# Conversational Interfaces: Users interact via chatbots or voice assistants (such as: asking questions, getting recommendations).
# Embedded Features: AI is integrated into apps for tasks like autocomplete, image recognition, or fraud detection.
# Decision Support: AI applications provide insights or predictions to help users make informed choices (such as: personalized shopping, medical diagnostics).
# Automation: They handle repetitive tasks, such as document processing or customer service, reducing manual effort.

# %%
#writing the file (overwriting)
with open(file="example.text" ,mode= "w") as file:
    file.write("Hello world\n")
    file.write("this is new line\n")

# %%
# writing the file (without overwriting)
with open (file ="example.text" , mode= "a") as file:
    file.write("Hello world 222\n")
    file.write("this is new line222")

# %%
# writing a list of line
lines="line \n line 2 \n line 3"
with open(file="example.text", mode="a") as file1:
    file1.writelines(lines)

# %%
# read binary file     
with open(file="example.bin", mode="rb") as file:
    content =file.read()
    print(content)
# Out:
# b'\x00\x01\x02\x03'

# %%
# write binary files
data = b'\x00\x01\x02\x03'
with open(file="example.bin" , mode= "wb") as file:
    file.write(data)

# %%
#read the content of example.text file and put in distination.text file
with open(file="example.text", mode="r") as file:
    content = file.read()

with open(file="destination.text", mode="w") as file1:
    file1.writelines(content)

# %%
def count_word(file_path):
    with open(file=file_path , mode="r") as file:
        lines = file.readlines()
        print(lines)
        print(type(lines))
        line_count= len(file)
        word_count= sum(len(line.split()) for line in lines)
        char_line = sum(len(line) for line in lines)
        print(line_count)
        print(char_line)
    return line_count , word_count, char_line
file ="example.text"
line, word , char= count_word(file)

print(line, word , char)
# Out:
# ['Hello world\n', 'this is new line\n', 'Hello world 222\n', 'this is new line222line \n', ' line 2 \n', ' line 3line \n', ' line 2 \n', ' line 3']
# <class 'list'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 13
#      11     return line_count , word_count, char_line
#      12 file ="example.text"
# ---> 13 line, word , char= count_word(file)
#      15 print(line, word , char)
#
# Cell In[34], line 6, in count_word(file_path)
#       4 print(lines)
#       5 print(type(lines))
# ----> 6 line_count= len(file)
#       7 word_count= sum(len(line.split()) for line in lines)
#       8 char_line = sum(len(line) for line in lines)
#
# TypeError: object of type '_io.TextIOWrapper' has no len()
