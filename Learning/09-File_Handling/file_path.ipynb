# %%
import os
cwd = os.getcwd()
print(cwd)
# Out:
# e:\Python\Learning\File_Handling

# %%
# create new director 
new_director = "package"
os.mkdir(new_director)

# %%
# list all dir in current folder
items= os.listdir(".")
print(items)
# Out:
# ['destination.text', 'example.bin', 'example.text', 'fileoperation.ipynb', 'file_path.ipynb', 'package']

# %%
# joining path
dir_name ="folder"
file_name ="file.txt"
full_path= os.path.join(os.getcwd(),dir_name, file_name)
print(full_path)
# Out:
# e:\Python\Learning\File_Handling\folder\file.txt

# %%
path = "example1.text"
if os.path.exists(path):
    print(f"file exist:{path}")
else :
    print(f"file not exist:{path}")
# Out:
# file not exist:example1.text

# %%
#check is path is file or director 
path = "example.text"
if os.path.isfile(path):
    print(f"path is file :{path}")
elif os.path.isdir(path):
    print(f"path is dir :{path}")
# Out:
# path is file :example.text

# %%
os.path.abspath(path)
# Out:
# 'e:\\Python\\Learning\\File_Handling\\example.text'
