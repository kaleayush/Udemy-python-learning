# %%
try:
    a=0/10
    print(a)
except ZeroDivisionError as ex:
    print(f"exception will occure :{ex}")

# %%
#try except, else
# if no exception occure then else will execute else if exception occure then no else will execute

# try except else finally
# if exception occure then no else will execute but finally will and if no exception then else will execute and finally will execute
