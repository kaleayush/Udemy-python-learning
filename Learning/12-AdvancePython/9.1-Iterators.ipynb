# %% [markdown]
# Iterator are advance py concepts that allows for efficient looping and memory management . iterators provide a way to access elements of a collection sequentially without exposing the underlying structure.

# %%
## Iterator
list=[1,2,34,5,67,]
iterator=iter(list)
print(type(iterator))
print(iterator)
# Out:
# <class 'list_iterator'>

# %%
iterator=iter(list)

# %%
try:
    print(next(iterator))
except StopIteration:
    print("their is no element in the list to show")
# Out:
# their is no element in the list to show
