# %%
# tuples 
#tuples are orderd collections of items that are immutable they are similar to lists bit their immutabilty makes then diff
empty_tuple = ()
print(empty_tuple)
print(type(empty_tuple))
# Out:
# ()
# <class 'tuple'>

# %%
list = list()
print(type(list))
tpl = tuple()
print(type(tpl))
# Out:
# <class 'list'>
# <class 'tuple'>

# %%
number = tuple([1,2,3,4,5,68,7])
number
# Out:
# (1, 2, 3, 4, 5, 68, 7)

# %%
list = list((1,2,4,5,6,6))
print(list)
# Out:
# [1, 2, 4, 5, 6, 6]

# %%
mixed_tuple = (1,"world", 3.14, False)
print(mixed_tuple)
# Out:
# (1, 'world', 3.14, False)

# %%
# accessing tuples
number
# Out:
# (1, 2, 3, 4, 5, 68, 7)

# %%
print(number[0])
print(number[-1])
print(number[len(number)//2])
print(number[-5])
number[0:4]
# Out:
# 1
# 7
# 4
# 3
# (1, 2, 3, 4)

# %%
print(number.count(1))
print(number.index(1))
# Out:
# 1
# 0

# %%
#tuples operation
concatination = number + mixed_tuple
print(concatination) 
mixed_tuple *3
number * 3
# Out:
# (1, 2, 3, 4, 5, 68, 7, 1, 'world', 3.14, False)
# (1, 2, 3, 4, 5, 68, 7, 1, 2, 3, 4, 5, 68, 7, 1, 2, 3, 4, 5, 68, 7)

# %%
#immutable nature of tuple 
# tuples are immutable means once value is assign its value can't be change
lst= [1,2,3,4,5]
print(lst)
lst[2] ="ayush"
print(lst)
# Out:
# [1, 2, 3, 4, 5]
# [1, 2, 'ayush', 4, 5]

# %%
print(number)
number[1] = "ayush"
print(number)
# Out:
# (1, 2, 3, 4, 5, 68, 7)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 print(number)
# ----> 2 number[1] = "ayush"
#       3 print(number)
#
# TypeError: 'tuple' object does not support item assignment

# %%
#tuple method 
# count function return no of count of 1 
print(number.count(1))
# index function return index of value 3 in tuple 
print(number.index(2))
# Out:
# 1
# 2

# %%
# packing and unpacking in tuple
paking_tupe = "ayush", 25 , "kale"
print(paking_tupe)
#name , age, lastname = paking_tupe
#print(name, age , lastname)
# Out:
# ('ayush', 25, 'kale')
# ayush 25 kale

# %%
#unpacking with *

paking_tuple = "ayush", 26 ,"kale", "indore", "ujjain","pune", "jalgaon"
name , age , lastname, *cityName= paking_tuple
print(name , age , lastname)
print(cityName)
# Out:
# ayush 26 kale
# ['indore', 'ujjain', 'pune', 'jalgaon']

# %%
# nested list 
list =[[1,2,3, 4],[4,5,6],["ayush", "kale"]]
print(list[0][1:3])
# Out:
# [2, 3]

# %%
# nested tuple 
tuple= ((1,2,3), ("ayush", "kale"),(True , False))
print(tuple[1])
print(tuple[1][1])
# Out:
# ('ayush', 'kale')
# kale

# %%
for tu in tuple:
    for t in tu:
        print(t, end=" ")
# Out:
# 1 2 3 ayush kale True False
